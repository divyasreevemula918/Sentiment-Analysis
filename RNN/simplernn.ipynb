# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.callbacks import EarlyStopping

max_features = 10000
max_length = 500

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)

X_train = pad_sequences(X_train, maxlen=max_length)
X_test = pad_sequences(X_test, maxlen=max_length)

model = Sequential()
model.add(Embedding(max_features, 128, input_length=max_length))
model.add(SimpleRNN(128, activation="tanh"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

earlystopping = EarlyStopping(
    monitor="val_loss",
    patience=2,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    validation_split=0.2,
    callbacks=[earlystopping]
)

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)

model.save("simple_rnn_imdb.keras")
# Out:
# WARNING:tensorflow:From c:\Users\divya\OneDrive\Desktop\Simple RNN\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\divya\OneDrive\Desktop\Simple RNN\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\divya\OneDrive\Desktop\Simple RNN\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/5
# WARNING:tensorflow:From c:\Users\divya\OneDrive\Desktop\Simple RNN\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\divya\OneDrive\Desktop\Simple RNN\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 625/625 [==============================] - 153s 239ms/step - loss: 0.6464 - accuracy: 0.6058 - val_loss: 0.5895 - val_accuracy: 0.6678
# Epoch 2/5
# 625/625 [==============================] - 164s 262ms/step - loss: 0.5329 - accuracy: 0.7273 - val_loss: 0.5869 - val_accuracy: 0.6846
# Epoch 3/5
# 625/625 [==============================] - 118s 188ms/step - loss: 0.4732 - accuracy: 0.7725 - val_loss: 0.5925 - val_accuracy: 0.7128
# Epoch 4/5
# 625/625 [==============================] - 135s 216ms/step - loss: 0.4048 - accuracy: 0.8126 - val_loss: 0.6106 - val_accuracy: 0.6606
# 782/782 [==============================] - 34s 43ms/step - loss: 0.5812 - accuracy: 0.6825
# Test Accuracy: 0.6825199723243713
